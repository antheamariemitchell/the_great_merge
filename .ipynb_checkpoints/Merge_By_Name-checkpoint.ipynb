# %%
import pandas as pd

# %%
cd the_great_merge/check_these
# Out:
# /Users/anthea.mitchell/Desktop/Coding/CSVs/the_great_merge/check_these

# %%
Main_List=pd.read_csv('Hamilton.csv')
new_csv = pd.read_csv('SP003098.csv')
Main_List
# Out:
#    Deep Well Position Tube Barcode
# 0                  B1    BXQ2HUHWN
# 1                  C1    BXR8L6M9N
# 2                  D1    BX7QU5HCS
# 3                  E1    BX6F574DD
# 4                  F1    BX6HEB8C2
# 5                  G1    BXERG1E2F
# 6                  A2    BXU6SBH94
# 7                  B2    BX84LKLBH
# 8                  C2    BXSAKABQH
# 9                  D2    BX17VEA8K
# 10                 E2    BX5V8PMFS
# 11                 F2    BXQ2AVRAR
# 12                 G2    BXK4WHNH6
# 13                 H2    BXT2E9FCV
# 14                 A3    BXWB3TGU8
# 15                 B3    BXN64T823
# 16                 C3    BXP9JLKPB
# 17                 D3    BX9RDLAK2
# 18                 E3    BXV9VBTDV
# 19                 F3    BXGWTUWEA
# 20                 G3    BXE2GUM7L
# 21                 H3    BXG5KJ5P9
# 22                 A4    BX2113DKJ
# 23                 B4    BXBQ6B4HP
# 24                 C4    BXGL7CL87
# 25                 D4    BXN9RBC68
# ...

# %%
Main_List = Main_List.drop_duplicates(subset=None, keep='first', inplace=False)
Main_List
New_doc = pd.merge(Main_List, new_csv, left_on=['barcode'], 
             right_on= ['sample_name'], how='left')
New_doc.to_csv('erg.csv')
